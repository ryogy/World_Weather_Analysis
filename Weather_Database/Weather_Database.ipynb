# %%
# All imports and dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import random
from citipy import citipy
import requests
from datetime import datetime
from config import weather_api_key

# %%
# Create set of random longitudes and latitudes
lats = np.random.uniform(low=-90.00, high=90.00, size=2000)
longs = np.random.uniform(low=-180.00, high=180.00, size=2000)
lat_longs = zip(lats, longs)
lat_longs

# %%
# Add lat_longs to a list to unpack data
coordinates = list(lat_longs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 737

# %%
# Define URL for API call on OpenWeatherMap
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
#Check to make sure it is a working url link
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5809be67b32647cbfb2afe6fa269d78d

# %%
# Create empty list to hold city weather data
city_data = []
# Print the beginning of the logging
print("Beginning Data Retrieval")
print("-----------------------------")

# Creating counters
record_count = 1
set_count = 1

# Looping through cities
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run city API request
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Weather Description": city_weather_description,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | kieta
# Processing Record 2 of Set 1 | rikitea
# Processing Record 3 of Set 1 | cherskiy
# Processing Record 4 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 5 of Set 1 | camacha
# Processing Record 6 of Set 1 | tautira
# Processing Record 7 of Set 1 | butaritari
# Processing Record 8 of Set 1 | kudahuvadhoo
# Processing Record 9 of Set 1 | ushuaia
# Processing Record 10 of Set 1 | fairbanks
# Processing Record 11 of Set 1 | kysyl-syr
# Processing Record 12 of Set 1 | amapa
# Processing Record 13 of Set 1 | chimbote
# Processing Record 14 of Set 1 | punta arenas
# Processing Record 15 of Set 1 | codrington
# Processing Record 16 of Set 1 | mar del plata
# Processing Record 17 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 18 of Set 1 | port alfred
# Processing Record 19 of Set 1 | grindavik
# Processing Record 20 of Set 1 | ancud
# Processing Record 21 of Set 1 | sambava
# Processing Record 22 of Set 1 | chuy
# Processing Record 23 of Set 1 | jamestown
# Processing Record 24 of Set 1 | ilulissat
# Processing Record 25 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 26 of Set 1 | hithadhoo
# Processing Record 27 of Set 1 | berlevag
# Processing Record 28 of Set 1 | tabory
# Processing Record 29 of Set 1 | baykit
# Processing Record 30 of Set 1 | mehamn
# Processing Record 31 of Set 1 | mahebourg
# Processing Record 32 of Set 1 | kaitangata
# Processing Record 33 of Set 1 | puerto ayora
# Processing Record 34 of Set 1 | nikolskoye
# Processing Record 35 of Set 1 | torbay
# Processing Record 36 of Set 1 | new norfolk
# Processing Record 37 of Set 1 | longyearbyen
# Processing Record 38 of Set 1 | buchanan
# Processing Record 39 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 40 of Set 1 | lebu
# Processing Record 41 of Set 1 | ahipara
# Processing Record 42 of Set 1 | henties bay
# Processing Record 43 of Set 1 | lagoa
# Processing Record 44 of Set 1 | barrow
# Processing Record 45 of Set 1 | albany
# Processing Record 46 of Set 1 | ribeira grande
# Processing Record 47 of Set 1 | saint-philippe
# Processing Record 48 of Set 1 | saint george
# Processing Record 49 of Set 1 | olinda
# Processing Record 50 of Set 1 | vaini
# Processing Record 1 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 2 of Set 2 | abakaliki
# Processing Record 3 of Set 2 | fortuna
# Processing Record 4 of Set 2 | guaruja
# Processing Record 5 of Set 2 | shchelyayur
# City not found. Skipping...
# Processing Record 6 of Set 2 | kapaa
# Processing Record 7 of Set 2 | bredasdorp
# Processing Record 8 of Set 2 | clyde river
# Processing Record 9 of Set 2 | atuona
# Processing Record 10 of Set 2 | norman wells
# Processing Record 11 of Set 2 | khorinsk
# Processing Record 12 of Set 2 | chokurdakh
# Processing Record 13 of Set 2 | tiksi
# Processing Record 14 of Set 2 | busselton
# Processing Record 15 of Set 2 | east london
# Processing Record 16 of Set 2 | huarmey
# Processing Record 17 of Set 2 | kamenka
# Processing Record 18 of Set 2 | prien
# Processing Record 19 of Set 2 | lopsmarka
# Processing Record 20 of Set 2 | narsaq
# Processing Record 21 of Set 2 | bluff
# Processing Record 22 of Set 2 | yellowknife
# Processing Record 23 of Set 2 | syzran
# Processing Record 24 of Set 2 | mucuri
# Processing Record 25 of Set 2 | vostok
# Processing Record 26 of Set 2 | kodiak
# Processing Record 27 of Set 2 | mataura
# Processing Record 28 of Set 2 | jamiltepec
# Processing Record 29 of Set 2 | bethel
# Processing Record 30 of Set 2 | roebourne
# Processing Record 31 of Set 2 | luena
# Processing Record 32 of Set 2 | lakes entrance
# Processing Record 33 of Set 2 | bekovo
# Processing Record 34 of Set 2 | kushima
# Processing Record 35 of Set 2 | gurupi
# Processing Record 36 of Set 2 | ampanihy
# Processing Record 37 of Set 2 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 38 of Set 2 | tessalit
# Processing Record 39 of Set 2 | aklavik
# Processing Record 40 of Set 2 | dingle
# Processing Record 41 of Set 2 | tasiilaq
# Processing Record 42 of Set 2 | lehigh acres
# Processing Record 43 of Set 2 | mochalishche
# Processing Record 44 of Set 2 | abha
# Processing Record 45 of Set 2 | imues
# Processing Record 46 of Set 2 | kuala terengganu
# Processing Record 47 of Set 2 | jining
# Processing Record 48 of Set 2 | capaci
# Processing Record 49 of Set 2 | ostrovnoy
# Processing Record 50 of Set 2 | lorengau
# Processing Record 1 of Set 3 | faanui
# Processing Record 2 of Set 3 | bilibino
# Processing Record 3 of Set 3 | aksarka
# Processing Record 4 of Set 3 | seguela
# Processing Record 5 of Set 3 | pevek
# Processing Record 6 of Set 3 | srandakan
# Processing Record 7 of Set 3 | avarua
# Processing Record 8 of Set 3 | sitka
# Processing Record 9 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 10 of Set 3 | golspie
# Processing Record 11 of Set 3 | dingli
# Processing Record 12 of Set 3 | kiama
# Processing Record 13 of Set 3 | serebryanyy bor
# Processing Record 14 of Set 3 | thompson
# Processing Record 15 of Set 3 | peterhead
# Processing Record 16 of Set 3 | yenagoa
# Processing Record 17 of Set 3 | deputatskiy
# Processing Record 18 of Set 3 | altay
# Processing Record 19 of Set 3 | flinders
# Processing Record 20 of Set 3 | vawkavysk
# Processing Record 21 of Set 3 | hermanus
# Processing Record 22 of Set 3 | inongo
# Processing Record 23 of Set 3 | jacareacanga
# Processing Record 24 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 25 of Set 3 | mahaicony
# City not found. Skipping...
# Processing Record 26 of Set 3 | auki
# Processing Record 27 of Set 3 | hoopstad
# Processing Record 28 of Set 3 | stephenville
# Processing Record 29 of Set 3 | mandalgovi
# Processing Record 30 of Set 3 | rahuri
# Processing Record 31 of Set 3 | jalu
# Processing Record 32 of Set 3 | mount gambier
# Processing Record 33 of Set 3 | moiyabana
# City not found. Skipping...
# Processing Record 34 of Set 3 | namibe
# Processing Record 35 of Set 3 | yilan
# Processing Record 36 of Set 3 | caernarfon
# Processing Record 37 of Set 3 | saint simons
# Processing Record 38 of Set 3 | kara-tyube
# Processing Record 39 of Set 3 | hambantota
# Processing Record 40 of Set 3 | jiuquan
# Processing Record 41 of Set 3 | kalabo
# Processing Record 42 of Set 3 | hobart
# Processing Record 43 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 44 of Set 3 | kismayo
# Processing Record 45 of Set 3 | tuktoyaktuk
# Processing Record 46 of Set 3 | gamba
# Processing Record 47 of Set 3 | peoria
# Processing Record 48 of Set 3 | khonuu
# City not found. Skipping...
# Processing Record 49 of Set 3 | caravelas
# Processing Record 50 of Set 3 | upernavik
# Processing Record 1 of Set 4 | maniitsoq
# Processing Record 2 of Set 4 | honiara
# Processing Record 3 of Set 4 | dikson
# Processing Record 4 of Set 4 | luderitz
# Processing Record 5 of Set 4 | hamilton
# Processing Record 6 of Set 4 | kaniv
# Processing Record 7 of Set 4 | port elizabeth
# Processing Record 8 of Set 4 | tura
# Processing Record 9 of Set 4 | port shepstone
# Processing Record 10 of Set 4 | lompoc
# Processing Record 11 of Set 4 | pisz
# Processing Record 12 of Set 4 | manacapuru
# Processing Record 13 of Set 4 | kutum
# Processing Record 14 of Set 4 | lavrentiya
# Processing Record 15 of Set 4 | manzhouli
# Processing Record 16 of Set 4 | ketchikan
# Processing Record 17 of Set 4 | saint-denis
# Processing Record 18 of Set 4 | cabra
# Processing Record 19 of Set 4 | coquimbo
# Processing Record 20 of Set 4 | avera
# Processing Record 21 of Set 4 | ercis
# Processing Record 22 of Set 4 | saldanha
# Processing Record 23 of Set 4 | carnarvon
# Processing Record 24 of Set 4 | seoul
# Processing Record 25 of Set 4 | porkhov
# Processing Record 26 of Set 4 | broome
# Processing Record 27 of Set 4 | mantua
# Processing Record 28 of Set 4 | alta floresta
# Processing Record 29 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 30 of Set 4 | moranbah
# Processing Record 31 of Set 4 | pingliang
# Processing Record 32 of Set 4 | mocambique
# City not found. Skipping...
# Processing Record 33 of Set 4 | christchurch
# Processing Record 34 of Set 4 | faya
# Processing Record 35 of Set 4 | hammerfest
# Processing Record 36 of Set 4 | madimba
# Processing Record 37 of Set 4 | santa maria
# Processing Record 38 of Set 4 | obama
# Processing Record 39 of Set 4 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 40 of Set 4 | aracaju
# Processing Record 41 of Set 4 | saint-joseph
# Processing Record 42 of Set 4 | tabas
# Processing Record 43 of Set 4 | bucerias
# Processing Record 44 of Set 4 | campos altos
# Processing Record 45 of Set 4 | kargopol
# Processing Record 46 of Set 4 | minot
# Processing Record 47 of Set 4 | belaya gora
# Processing Record 48 of Set 4 | zhitikara
# City not found. Skipping...
# Processing Record 49 of Set 4 | limbang
# Processing Record 50 of Set 4 | san patricio
# Processing Record 1 of Set 5 | rabo de peixe
# Processing Record 2 of Set 5 | hailey
# Processing Record 3 of Set 5 | pisco
# Processing Record 4 of Set 5 | srednekolymsk
# Processing Record 5 of Set 5 | bonavista
# Processing Record 6 of Set 5 | pemangkat
# Processing Record 7 of Set 5 | khatanga
# Processing Record 8 of Set 5 | garowe
# Processing Record 9 of Set 5 | qaanaaq
# Processing Record 10 of Set 5 | esperance
# Processing Record 11 of Set 5 | coihaique
# Processing Record 12 of Set 5 | noumea
# Processing Record 13 of Set 5 | cidreira
# Processing Record 14 of Set 5 | bonoua
# Processing Record 15 of Set 5 | imbituba
# Processing Record 16 of Set 5 | kahului
# Processing Record 17 of Set 5 | riyadh
# Processing Record 18 of Set 5 | deniliquin
# Processing Record 19 of Set 5 | korablino
# Processing Record 20 of Set 5 | la ronge
# Processing Record 21 of Set 5 | ponta do sol
# Processing Record 22 of Set 5 | marystown
# Processing Record 23 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 24 of Set 5 | nantucket
# Processing Record 25 of Set 5 | talnakh
# Processing Record 26 of Set 5 | tres arroyos
# Processing Record 27 of Set 5 | poum
# Processing Record 28 of Set 5 | mahina
# Processing Record 29 of Set 5 | cape town
# Processing Record 30 of Set 5 | alice springs
# Processing Record 31 of Set 5 | polyanka
# Processing Record 32 of Set 5 | padang
# Processing Record 33 of Set 5 | makakilo city
# Processing Record 34 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 35 of Set 5 | korla
# Processing Record 36 of Set 5 | midland
# Processing Record 37 of Set 5 | bambous virieux
# Processing Record 38 of Set 5 | sept-iles
# Processing Record 39 of Set 5 | port-gentil
# Processing Record 40 of Set 5 | tual
# Processing Record 41 of Set 5 | wanning
# Processing Record 42 of Set 5 | richards bay
# Processing Record 43 of Set 5 | pavilosta
# Processing Record 44 of Set 5 | saint anthony
# Processing Record 45 of Set 5 | saskylakh
# Processing Record 46 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 47 of Set 5 | nyandoma
# Processing Record 48 of Set 5 | mariental
# Processing Record 49 of Set 5 | nuuk
# Processing Record 50 of Set 5 | mayo
# Processing Record 1 of Set 6 | bathsheba
# Processing Record 2 of Set 6 | saryshagan
# City not found. Skipping...
# Processing Record 3 of Set 6 | bengkulu
# Processing Record 4 of Set 6 | zhemchuzhnyy
# City not found. Skipping...
# Processing Record 5 of Set 6 | tawnat
# City not found. Skipping...
# Processing Record 6 of Set 6 | nacala
# Processing Record 7 of Set 6 | calamar
# Processing Record 8 of Set 6 | katsuura
# Processing Record 9 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 10 of Set 6 | rawson
# Processing Record 11 of Set 6 | lubbock
# Processing Record 12 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 13 of Set 6 | aloleng
# Processing Record 14 of Set 6 | shakhtinsk
# Processing Record 15 of Set 6 | floro
# Processing Record 16 of Set 6 | vila velha
# Processing Record 17 of Set 6 | biloela
# Processing Record 18 of Set 6 | husavik
# Processing Record 19 of Set 6 | abu samrah
# Processing Record 20 of Set 6 | burnie
# Processing Record 21 of Set 6 | guerrero negro
# Processing Record 22 of Set 6 | lata
# Processing Record 23 of Set 6 | sao luiz gonzaga
# Processing Record 24 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 25 of Set 6 | lodja
# Processing Record 26 of Set 6 | preobrazheniye
# Processing Record 27 of Set 6 | inirida
# Processing Record 28 of Set 6 | chifeng
# Processing Record 29 of Set 6 | taoudenni
# Processing Record 30 of Set 6 | castro
# Processing Record 31 of Set 6 | juybar
# Processing Record 32 of Set 6 | arraial do cabo
# Processing Record 33 of Set 6 | ayagoz
# Processing Record 34 of Set 6 | broken hill
# Processing Record 35 of Set 6 | nhulunbuy
# Processing Record 36 of Set 6 | lukiv
# Processing Record 37 of Set 6 | te anau
# Processing Record 38 of Set 6 | cabo san lucas
# Processing Record 39 of Set 6 | najran
# Processing Record 40 of Set 6 | bose
# Processing Record 41 of Set 6 | novikovo
# Processing Record 42 of Set 6 | elk
# Processing Record 43 of Set 6 | terney
# Processing Record 44 of Set 6 | zhigansk
# Processing Record 45 of Set 6 | vallenar
# Processing Record 46 of Set 6 | atbasar
# Processing Record 47 of Set 6 | san pedro
# Processing Record 48 of Set 6 | champerico
# Processing Record 49 of Set 6 | mora
# Processing Record 50 of Set 6 | sishui
# Processing Record 1 of Set 7 | garzon
# Processing Record 2 of Set 7 | mikuni
# Processing Record 3 of Set 7 | gimbi
# Processing Record 4 of Set 7 | maragogi
# Processing Record 5 of Set 7 | kruisfontein
# Processing Record 6 of Set 7 | georgetown
# Processing Record 7 of Set 7 | sayyan
# Processing Record 8 of Set 7 | berlin
# Processing Record 9 of Set 7 | dawei
# Processing Record 10 of Set 7 | saint-pierre
# Processing Record 11 of Set 7 | puerto escondido
# Processing Record 12 of Set 7 | sakakah
# Processing Record 13 of Set 7 | puerto gaitan
# Processing Record 14 of Set 7 | asfi
# Processing Record 15 of Set 7 | marrakesh
# Processing Record 16 of Set 7 | klaksvik
# Processing Record 17 of Set 7 | dicabisagan
# Processing Record 18 of Set 7 | cusset
# Processing Record 19 of Set 7 | svetlogorsk
# Processing Record 20 of Set 7 | rupert
# Processing Record 21 of Set 7 | sao filipe
# Processing Record 22 of Set 7 | tuatapere
# Processing Record 23 of Set 7 | waipawa
# Processing Record 24 of Set 7 | chapais
# Processing Record 25 of Set 7 | tunduru
# City not found. Skipping...
# Processing Record 26 of Set 7 | morant bay
# Processing Record 27 of Set 7 | svetlyy yar
# Processing Record 28 of Set 7 | adrar
# Processing Record 29 of Set 7 | ca mau
# Processing Record 30 of Set 7 | talaya
# Processing Record 31 of Set 7 | payo
# Processing Record 32 of Set 7 | umm lajj
# Processing Record 33 of Set 7 | atar
# Processing Record 34 of Set 7 | wanaka
# Processing Record 35 of Set 7 | shenkursk
# Processing Record 36 of Set 7 | plaeng yao
# Processing Record 37 of Set 7 | severo-kurilsk
# Processing Record 38 of Set 7 | aden
# Processing Record 39 of Set 7 | malwan
# City not found. Skipping...
# Processing Record 40 of Set 7 | marawi
# Processing Record 41 of Set 7 | hilo
# Processing Record 42 of Set 7 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 43 of Set 7 | san quintin
# Processing Record 44 of Set 7 | byron bay
# Processing Record 45 of Set 7 | akyab
# Processing Record 46 of Set 7 | anchorage
# Processing Record 47 of Set 7 | touros
# Processing Record 48 of Set 7 | mogadishu
# Processing Record 49 of Set 7 | kaabong
# Processing Record 50 of Set 7 | margate
# Processing Record 1 of Set 8 | manggar
# Processing Record 2 of Set 8 | sola
# Processing Record 3 of Set 8 | okakarara
# Processing Record 4 of Set 8 | serra talhada
# Processing Record 5 of Set 8 | nishihara
# Processing Record 6 of Set 8 | san andres
# Processing Record 7 of Set 8 | xihe
# Processing Record 8 of Set 8 | yerbogachen
# Processing Record 9 of Set 8 | ongandjera
# Processing Record 10 of Set 8 | krasnaya gora
# Processing Record 11 of Set 8 | hovd
# Processing Record 12 of Set 8 | vila franca do campo
# Processing Record 13 of Set 8 | maceio
# Processing Record 14 of Set 8 | mahon
# Processing Record 15 of Set 8 | acapulco
# Processing Record 16 of Set 8 | pontianak
# Processing Record 17 of Set 8 | mackay
# Processing Record 18 of Set 8 | yirol
# City not found. Skipping...
# Processing Record 19 of Set 8 | qurayyat
# Processing Record 20 of Set 8 | susurluk
# Processing Record 21 of Set 8 | lolua
# City not found. Skipping...
# Processing Record 22 of Set 8 | laguna
# Processing Record 23 of Set 8 | san juan evangelista
# Processing Record 24 of Set 8 | lisakovsk
# Processing Record 25 of Set 8 | southbridge
# Processing Record 26 of Set 8 | vao
# Processing Record 27 of Set 8 | bilma
# Processing Record 28 of Set 8 | vardo
# Processing Record 29 of Set 8 | oranjemund
# Processing Record 30 of Set 8 | sioux lookout
# Processing Record 31 of Set 8 | micheweni
# Processing Record 32 of Set 8 | sabang
# Processing Record 33 of Set 8 | inuvik
# Processing Record 34 of Set 8 | namatanai
# Processing Record 35 of Set 8 | norfolk
# Processing Record 36 of Set 8 | mendoza
# Processing Record 37 of Set 8 | gazli
# Processing Record 38 of Set 8 | itoman
# Processing Record 39 of Set 8 | tomatlan
# Processing Record 40 of Set 8 | bintulu
# Processing Record 41 of Set 8 | naze
# Processing Record 42 of Set 8 | svetlaya
# Processing Record 43 of Set 8 | mayskiy
# Processing Record 44 of Set 8 | skelleftea
# Processing Record 45 of Set 8 | banda aceh
# Processing Record 46 of Set 8 | carutapera
# Processing Record 47 of Set 8 | grand-lahou
# Processing Record 48 of Set 8 | pochutla
# Processing Record 49 of Set 8 | chicama
# Processing Record 50 of Set 8 | verkhnyaya inta
# Processing Record 1 of Set 9 | souillac
# Processing Record 2 of Set 9 | channel-port aux basques
# Processing Record 3 of Set 9 | provideniya
# Processing Record 4 of Set 9 | arlit
# Processing Record 5 of Set 9 | leh
# Processing Record 6 of Set 9 | plettenberg bay
# Processing Record 7 of Set 9 | toliary
# City not found. Skipping...
# Processing Record 8 of Set 9 | jiroft
# City not found. Skipping...
# Processing Record 9 of Set 9 | jumla
# Processing Record 10 of Set 9 | ixtapa
# Processing Record 11 of Set 9 | surt
# Processing Record 12 of Set 9 | qaqortoq
# Processing Record 13 of Set 9 | nome
# Processing Record 14 of Set 9 | ahome
# Processing Record 15 of Set 9 | itamaraca
# Processing Record 16 of Set 9 | litoral del san juan
# City not found. Skipping...
# Processing Record 17 of Set 9 | college
# Processing Record 18 of Set 9 | shimoda
# Processing Record 19 of Set 9 | panama city
# Processing Record 20 of Set 9 | mishkino
# Processing Record 21 of Set 9 | cordenons
# Processing Record 22 of Set 9 | izumo
# Processing Record 23 of Set 9 | rio grande
# Processing Record 24 of Set 9 | khandyga
# Processing Record 25 of Set 9 | torata
# Processing Record 26 of Set 9 | mtimbira
# Processing Record 27 of Set 9 | kadykchan
# City not found. Skipping...
# Processing Record 28 of Set 9 | birin
# Processing Record 29 of Set 9 | celestun
# Processing Record 30 of Set 9 | airai
# Processing Record 31 of Set 9 | sovetskaya gavan
# Processing Record 32 of Set 9 | viseu
# Processing Record 33 of Set 9 | victoria
# Processing Record 34 of Set 9 | oksovskiy
# Processing Record 35 of Set 9 | awbari
# Processing Record 36 of Set 9 | copiapo
# Processing Record 37 of Set 9 | mapiripan
# Processing Record 38 of Set 9 | grand gaube
# Processing Record 39 of Set 9 | lubao
# Processing Record 40 of Set 9 | eyl
# Processing Record 41 of Set 9 | leningradskiy
# Processing Record 42 of Set 9 | sobolevo
# Processing Record 43 of Set 9 | katobu
# Processing Record 44 of Set 9 | platanos
# Processing Record 45 of Set 9 | portel
# Processing Record 46 of Set 9 | virginia beach
# Processing Record 47 of Set 9 | olafsvik
# Processing Record 48 of Set 9 | andenes
# Processing Record 49 of Set 9 | durban
# Processing Record 50 of Set 9 | constitucion
# Processing Record 1 of Set 10 | dharchula
# Processing Record 2 of Set 10 | oktyabrskiy
# Processing Record 3 of Set 10 | mokhsogollokh
# Processing Record 4 of Set 10 | chardara
# Processing Record 5 of Set 10 | mumford
# Processing Record 6 of Set 10 | obidos
# Processing Record 7 of Set 10 | sokoto
# Processing Record 8 of Set 10 | geraldton
# Processing Record 9 of Set 10 | kiunga
# Processing Record 10 of Set 10 | kavaratti
# Processing Record 11 of Set 10 | dunedin
# Processing Record 12 of Set 10 | nanortalik
# Processing Record 13 of Set 10 | san jose
# Processing Record 14 of Set 10 | buraydah
# Processing Record 15 of Set 10 | salalah
# Processing Record 16 of Set 10 | qujing
# Processing Record 17 of Set 10 | dahuk
# Processing Record 18 of Set 10 | sakaiminato
# Processing Record 19 of Set 10 | bulawayo
# Processing Record 20 of Set 10 | xuddur
# Processing Record 21 of Set 10 | neringa
# Processing Record 22 of Set 10 | bogorodskoye
# Processing Record 23 of Set 10 | mareeba
# Processing Record 24 of Set 10 | majene
# Processing Record 25 of Set 10 | carstairs
# Processing Record 26 of Set 10 | french harbor
# Processing Record 27 of Set 10 | mehriz
# Processing Record 28 of Set 10 | smithers
# Processing Record 29 of Set 10 | pueblo
# Processing Record 30 of Set 10 | itiuba
# Processing Record 31 of Set 10 | komsomolskiy
# Processing Record 32 of Set 10 | morondava
# Processing Record 33 of Set 10 | marcona
# City not found. Skipping...
# Processing Record 34 of Set 10 | portland
# Processing Record 35 of Set 10 | asau
# Processing Record 36 of Set 10 | chabahar
# Processing Record 37 of Set 10 | burica
# City not found. Skipping...
# Processing Record 38 of Set 10 | ilo
# Processing Record 39 of Set 10 | antofagasta
# Processing Record 40 of Set 10 | kutulik
# Processing Record 41 of Set 10 | mikhaylovka
# Processing Record 42 of Set 10 | bargal
# City not found. Skipping...
# Processing Record 43 of Set 10 | lawrence
# Processing Record 44 of Set 10 | honolulu
# Processing Record 45 of Set 10 | benidorm
# Processing Record 46 of Set 10 | bijawar
# Processing Record 47 of Set 10 | marzuq
# Processing Record 48 of Set 10 | kavieng
# Processing Record 49 of Set 10 | mount isa
# Processing Record 50 of Set 10 | drovyanaya
# Processing Record 1 of Set 11 | muli
# Processing Record 2 of Set 11 | barstow
# Processing Record 3 of Set 11 | pangoa
# Processing Record 4 of Set 11 | himora
# City not found. Skipping...
# Processing Record 5 of Set 11 | igrim
# Processing Record 6 of Set 11 | red bluff
# Processing Record 7 of Set 11 | novopavlovka
# Processing Record 8 of Set 11 | diego de almagro
# Processing Record 9 of Set 11 | khorixas
# Processing Record 10 of Set 11 | zwedru
# Processing Record 11 of Set 11 | bandar
# Processing Record 12 of Set 11 | champasak
# Processing Record 13 of Set 11 | illela
# Processing Record 14 of Set 11 | shestakovo
# Processing Record 15 of Set 11 | samarai
# Processing Record 16 of Set 11 | ginir
# Processing Record 17 of Set 11 | issa
# Processing Record 18 of Set 11 | zaysan
# Processing Record 19 of Set 11 | grenada
# Processing Record 20 of Set 11 | the valley
# Processing Record 21 of Set 11 | colquechaca
# Processing Record 22 of Set 11 | iqaluit
# Processing Record 23 of Set 11 | ucluelet
# Processing Record 24 of Set 11 | kedrovyy
# Processing Record 25 of Set 11 | svobodnyy
# Processing Record 26 of Set 11 | honggang
# Processing Record 27 of Set 11 | eggenfelden
# Processing Record 28 of Set 11 | harper
# Processing Record 29 of Set 11 | bhadrachalam
# Processing Record 30 of Set 11 | mizpe ramon
# City not found. Skipping...
# Processing Record 31 of Set 11 | ibra
# Processing Record 32 of Set 11 | hasaki
# Processing Record 33 of Set 11 | zyryanka
# Processing Record 34 of Set 11 | makung
# City not found. Skipping...
# Processing Record 35 of Set 11 | los llanos de aridane
# Processing Record 36 of Set 11 | belle fourche
# Processing Record 37 of Set 11 | port lincoln
# Processing Record 38 of Set 11 | tulsipur
# Processing Record 39 of Set 11 | ksenyevka
# City not found. Skipping...
# Processing Record 40 of Set 11 | si sa ket
# Processing Record 41 of Set 11 | ferrol
# Processing Record 42 of Set 11 | staroutkinsk
# Processing Record 43 of Set 11 | jumilla
# Processing Record 44 of Set 11 | mayumba
# Processing Record 45 of Set 11 | nara
# Processing Record 46 of Set 11 | olga
# Processing Record 47 of Set 11 | haines junction
# Processing Record 48 of Set 11 | waingapu
# Processing Record 49 of Set 11 | cabinda
# Processing Record 50 of Set 11 | buin
# Processing Record 1 of Set 12 | batagay-alyta
# Processing Record 2 of Set 12 | cayenne
# Processing Record 3 of Set 12 | rungata
# City not found. Skipping...
# Processing Record 4 of Set 12 | xining
# Processing Record 5 of Set 12 | rorvik
# Processing Record 6 of Set 12 | wawa
# Processing Record 7 of Set 12 | juegang
# Processing Record 8 of Set 12 | neiafu
# Processing Record 9 of Set 12 | pangai
# Processing Record 10 of Set 12 | ekibastuz
# Processing Record 11 of Set 12 | sinnamary
# Processing Record 12 of Set 12 | kamenskoye
# City not found. Skipping...
# Processing Record 13 of Set 12 | payakumbuh
# Processing Record 14 of Set 12 | kincardine
# Processing Record 15 of Set 12 | moindou
# Processing Record 16 of Set 12 | morlaix
# Processing Record 17 of Set 12 | kadoshkino
# Processing Record 18 of Set 12 | silver city
# Processing Record 19 of Set 12 | el alto
# Processing Record 20 of Set 12 | los algarrobos
# Processing Record 21 of Set 12 | mawlaik
# Processing Record 22 of Set 12 | bollnas
# Processing Record 23 of Set 12 | prachuap khiri khan
# Processing Record 24 of Set 12 | sandnessjoen
# Processing Record 25 of Set 12 | bousso
# Processing Record 26 of Set 12 | kuytun
# Processing Record 27 of Set 12 | vila
# Processing Record 28 of Set 12 | rocha
# Processing Record 29 of Set 12 | karatau
# Processing Record 30 of Set 12 | nazare
# Processing Record 31 of Set 12 | ewa beach
# Processing Record 32 of Set 12 | mineiros
# Processing Record 33 of Set 12 | palabuhanratu
# City not found. Skipping...
# Processing Record 34 of Set 12 | barkhan
# Processing Record 35 of Set 12 | tawkar
# City not found. Skipping...
# Processing Record 36 of Set 12 | amiens
# Processing Record 37 of Set 12 | qasigiannguit
# Processing Record 38 of Set 12 | havre-saint-pierre
# Processing Record 39 of Set 12 | comitan
# Processing Record 40 of Set 12 | kalmunai
# Processing Record 41 of Set 12 | ikalamavony
# Processing Record 42 of Set 12 | camopi
# Processing Record 43 of Set 12 | shenjiamen
# Processing Record 44 of Set 12 | tukrah
# Processing Record 45 of Set 12 | kopavogur
# Processing Record 46 of Set 12 | owando
# Processing Record 47 of Set 12 | evanston
# Processing Record 48 of Set 12 | panguna
# Processing Record 49 of Set 12 | port hueneme
# Processing Record 50 of Set 12 | iskateley
# Processing Record 1 of Set 13 | nakskov
# Processing Record 2 of Set 13 | gustavo diaz ordaz
# Processing Record 3 of Set 13 | turukhansk
# Processing Record 4 of Set 13 | sangar
# Processing Record 5 of Set 13 | zatreni
# Processing Record 6 of Set 13 | muros
# Processing Record 7 of Set 13 | sorvag
# City not found. Skipping...
# Processing Record 8 of Set 13 | marsa matruh
# Processing Record 9 of Set 13 | magadan
# Processing Record 10 of Set 13 | zlatoustovsk
# City not found. Skipping...
# Processing Record 11 of Set 13 | ivanava
# Processing Record 12 of Set 13 | tazmalt
# Processing Record 13 of Set 13 | fort nelson
# Processing Record 14 of Set 13 | nador
# Processing Record 15 of Set 13 | honiton
# Processing Record 16 of Set 13 | nizhnevartovsk
# Processing Record 17 of Set 13 | tuy hoa
# Processing Record 18 of Set 13 | bull savanna
# Processing Record 19 of Set 13 | winona
# Processing Record 20 of Set 13 | rovaniemi
# Processing Record 21 of Set 13 | jawhar
# Processing Record 22 of Set 13 | kattivakkam
# Processing Record 23 of Set 13 | cucuta
# Processing Record 24 of Set 13 | palaiokhorion
# Processing Record 25 of Set 13 | jiazi
# Processing Record 26 of Set 13 | shakiso
# Processing Record 27 of Set 13 | thinadhoo
# Processing Record 28 of Set 13 | ciudad bolivar
# Processing Record 29 of Set 13 | san rafael del sur
# Processing Record 30 of Set 13 | menongue
# Processing Record 31 of Set 13 | inhambane
# Processing Record 32 of Set 13 | pontes e lacerda
# Processing Record 33 of Set 13 | karaul
# City not found. Skipping...
# Processing Record 34 of Set 13 | tucurui
# Processing Record 35 of Set 13 | miranda
# Processing Record 36 of Set 13 | lucapa
# Processing Record 37 of Set 13 | amahai
# Processing Record 38 of Set 13 | constantine
# Processing Record 39 of Set 13 | voh
# Processing Record 40 of Set 13 | tolaga bay
# Processing Record 41 of Set 13 | pangnirtung
# Processing Record 42 of Set 13 | flin flon
# Processing Record 43 of Set 13 | santa vitoria do palmar
# Processing Record 44 of Set 13 | chingirlau
# Processing Record 45 of Set 13 | cabo rojo
# Processing Record 46 of Set 13 | jose bonifacio
# Processing Record 47 of Set 13 | lewiston
# Processing Record 48 of Set 13 | kuching
# Processing Record 49 of Set 13 | whitehorse
# Processing Record 50 of Set 13 | gunjur
# Processing Record 1 of Set 14 | port hardy
# Processing Record 2 of Set 14 | okhotsk
# Processing Record 3 of Set 14 | puerto narino
# Processing Record 4 of Set 14 | bismil
# Processing Record 5 of Set 14 | searcy
# Processing Record 6 of Set 14 | kinablangan
# Processing Record 7 of Set 14 | paamiut
# Processing Record 8 of Set 14 | nizwa
# Processing Record 9 of Set 14 | bandarbeyla
# Processing Record 10 of Set 14 | dubenskiy
# City not found. Skipping...
# Processing Record 11 of Set 14 | alofi
# Processing Record 12 of Set 14 | rwamagana
# Processing Record 13 of Set 14 | kastoria
# Processing Record 14 of Set 14 | indaiatuba
# Processing Record 15 of Set 14 | vestmannaeyjar
# Processing Record 16 of Set 14 | cuiluan
# Processing Record 17 of Set 14 | suntar
# Processing Record 18 of Set 14 | homa bay
# Processing Record 19 of Set 14 | podosinovets
# Processing Record 20 of Set 14 | gao
# Processing Record 21 of Set 14 | ostersund
# Processing Record 22 of Set 14 | utiroa
# City not found. Skipping...
# Processing Record 23 of Set 14 | neryungri
# Processing Record 24 of Set 14 | fenoarivo
# Processing Record 25 of Set 14 | tambopata
# Processing Record 26 of Set 14 | mattru
# Processing Record 27 of Set 14 | vicuna
# Processing Record 28 of Set 14 | rawlins
# Processing Record 29 of Set 14 | lukovetskiy
# Processing Record 30 of Set 14 | pinega
# Processing Record 31 of Set 14 | karratha
# Processing Record 32 of Set 14 | ondorhaan
# City not found. Skipping...
# Processing Record 33 of Set 14 | suphan buri
# Processing Record 34 of Set 14 | roald
# Processing Record 35 of Set 14 | fernley
# Processing Record 36 of Set 14 | warqla
# City not found. Skipping...
# Processing Record 37 of Set 14 | presidente dutra
# Processing Record 38 of Set 14 | hobyo
# Processing Record 39 of Set 14 | bonthe
# Processing Record 40 of Set 14 | roma
# Processing Record 41 of Set 14 | buzuluk
# Processing Record 42 of Set 14 | khani
# Processing Record 43 of Set 14 | hargeysa
# Processing Record 44 of Set 14 | anadyr
# Processing Record 45 of Set 14 | acarau
# Processing Record 46 of Set 14 | gharo
# Processing Record 47 of Set 14 | port keats
# Processing Record 48 of Set 14 | araouane
# Processing Record 49 of Set 14 | kimbe
# Processing Record 50 of Set 14 | kusti
# Processing Record 1 of Set 15 | khasan
# Processing Record 2 of Set 15 | verkhoyansk
# Processing Record 3 of Set 15 | katangli
# Processing Record 4 of Set 15 | kribi
# Processing Record 5 of Set 15 | ponta pora
# Processing Record 6 of Set 15 | enfield
# Processing Record 7 of Set 15 | nouadhibou
# Processing Record 8 of Set 15 | kirakira
# Processing Record 9 of Set 15 | evensk
# Processing Record 10 of Set 15 | hirara
# Processing Record 11 of Set 15 | karasjok
# Processing Record 12 of Set 15 | orlik
# Processing Record 13 of Set 15 | amos
# Processing Record 14 of Set 15 | mamallapuram
# Processing Record 15 of Set 15 | isangel
# Processing Record 16 of Set 15 | quatre cocos
# Processing Record 17 of Set 15 | wasilla
# Processing Record 18 of Set 15 | coari
# Processing Record 19 of Set 15 | northam
# Processing Record 20 of Set 15 | cascais
# Processing Record 21 of Set 15 | abu dhabi
# Processing Record 22 of Set 15 | esmeraldas
# Processing Record 23 of Set 15 | cap malheureux
# Processing Record 24 of Set 15 | vanimo
# Processing Record 25 of Set 15 | mahanoro
# Processing Record 26 of Set 15 | akranes
# Processing Record 27 of Set 15 | ajdabiya
# Processing Record 28 of Set 15 | russell
# Processing Record 29 of Set 15 | kiruna
# Processing Record 30 of Set 15 | yar-sale
# Processing Record 31 of Set 15 | koroni
# Processing Record 32 of Set 15 | elko
# Processing Record 33 of Set 15 | biak
# Processing Record 34 of Set 15 | kenai
# Processing Record 35 of Set 15 | collie
# Processing Record 36 of Set 15 | maiduguri
# Processing Record 37 of Set 15 | calvinia
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#        City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0     Kieta  -6.2167  155.6333     78.75        84          46        6.35
# 1   Rikitea -23.1203 -134.9692     73.02        77           2       14.00
# 2  Cherskiy  68.7500  161.3000     30.04        74          59        4.36
# 3   Camacha  33.0833  -16.3333     72.82        69          20       12.66
# 4   Tautira -17.7333 -149.1500     77.02        75          25       18.30
#
#   Current Weather Description Country                 Date
# 0                  light rain      PG  2021-09-16 09:10:13
# 1                   clear sky      PF  2021-09-16 09:10:14
# 2               broken clouds      RU  2021-09-16 09:10:14
# 3                  few clouds      PT  2021-09-16 09:10:15
# 4            scattered clouds      PF  2021-09-16 09:10:16

# %%
new_column_order = ["City", "Country", 
                    "Lat", "Lng", "Max Temp", 
                    "Humidity", "Cloudiness", "Wind Speed", "Current Weather Description"]
city_data_df = city_data_df[new_column_order]

city_data_df.head()
# Out:
#        City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Kieta      PG  -6.2167  155.6333     78.75        84          46
# 1   Rikitea      PF -23.1203 -134.9692     73.02        77           2
# 2  Cherskiy      RU  68.7500  161.3000     30.04        74          59
# 3   Camacha      PT  33.0833  -16.3333     72.82        69          20
# 4   Tautira      PF -17.7333 -149.1500     77.02        75          25
#
#    Wind Speed Current Weather Description
# 0        6.35                  light rain
# 1       14.00                   clear sky
# 2        4.36               broken clouds
# 3       12.66                  few clouds
# 4       18.30            scattered clouds

# %%
# Create output file
output_data_file = "WeatherPy_Database.csv"

#Export to .csv
city_data_df.to_csv(output_data_file, index_label='City_ID')
